# %% [markdown]
# # Property-based testing with Hypothesis
#
# Typically when we test software, we use *example*-based testing. We manually think of sets of inputs (i.e., examples) to pass into a function and see if it performs as expected. We've learnt many techniques to come up with these examples, like boundary-value testing, equivalence class, and decision tables. The problem is that this type of testing only tells you your program works as intended for those specific test cases *only*.
#
# Instead of relying on specific test cases, *property*-based testing, gauruntees that your programs work for *all data matching some specification*. So for an adder(x, y) function, instead of checking just (3,4), (0,1) and (2,3) etc., with property-based testing you can check that your program works for any given *int* inputs. This is really useful, especially in cases where you can't see the code, i.e., functional testing, or a low-trust environment.
#
# Let's see that in action:

# %% [markdown]
# This demo should only require the Hypothesis package, everything else is standard. Uncomment and run the cell below to install Hypothesis via pip, conda users you'll know what to do.

# %%
#!pip install hypothesis

# %% [markdown]
# ## A devious adder function
#
# Let's say you're a testing a few adder programs that takes two integers and returns the result. We'll have to pretend we can't see the code.

# %%
# Here's a normal adder function

def adder(x, y):
    return x + y

# And here is a malicious adder function

def bad_adder(x, y):
    if x>1000000000:
        return  "1; DROP TABLE users;"
    else:
        return x + y

# %% [markdown]
# The bad_adder function attempts an sql injection attack. So if the addition fucntion was being used to dynamically fill in a query, it could cause all kinds of trouble, viz:
#
# ```
# SELECT * FROM users WHERE user_id = {bad_adder(x,y)};
#
# if x = 42 then
#
# SELECT * FROM users WHERE user_id = 1; DROP TABLE users;
#
# This causes the users table to be deleted!!
# ```

# %% [markdown]
# With example based testing you'd test these functions like this:

# %%
import unittest

class AdderTestBase(unittest.TestCase):
    adder = None  # Placeholder for the adder function to be set by subclasses

    def test_positive_numbers(self):
        self.assertEqual(self.adder(1, 2), 3)
        self.assertEqual(self.adder(10, 5), 15)

    def test_negative_numbers(self):
        self.assertEqual(self.adder(-1, -2), -3)
        self.assertEqual(self.adder(-10, -5), -15)

    def test_mixed_numbers(self):
        self.assertEqual(self.adder(-1, 1), 0)
        self.assertEqual(self.adder(-10, 5), -5)

    def test_zero(self):
        self.assertEqual(self.adder(0, 0), 0)
        self.assertEqual(self.adder(0, 5), 5)
        self.assertEqual(self.adder(5, 0), 5)

# Testing the correct implementation
class TestSimpleAdder(AdderTestBase):
    adder = staticmethod(adder)

# Testing the incorrect implementation
class TestBadAdder(AdderTestBase):
    adder = staticmethod(bad_adder)

if __name__ == '__main__':
    # Only load subclasses, not AdderTestBase itself
    loader = unittest.TestLoader()
    suite = unittest.TestSuite()
    suite.addTests(loader.loadTestsFromTestCase(TestSimpleAdder))
    suite.addTests(loader.loadTestsFromTestCase(TestBadAdder))

    runner = unittest.TextTestRunner()
    runner.run(suite)
# Out:
# ........
# ----------------------------------------------------------------------
# Ran 8 tests in 0.004s
#
# OK

# %% [markdown]
# The tests passed so things look good right? Let's see what Hypothesis finds. To use Hypothesis:
# 1. Create test function that asserts the result of a function being tested to a trusted implementation (in this case I'll compare the result of adder() to Python's built-in add())
# 2. Using the @given decorator, tell Hypothesis what the types of the inputs are: @given(st.integers(), st.integers()) tells Hypothesis to test integer inputs for both arguments of the function.
#
# What is st.? It refers to Hypothesis strategies, these are intelligent sequence of values from the type that Hypothesis will try out, such as extremely small values, huge values, zero values, plus/minus. Think of it like automated equivalence class testing.

# %%
from hypothesis import given, strategies as st
import operator
import unittest

@given(st.integers(), st.integers())
def test_adder(x, y):
    assert adder(x, y) == operator.add(x, y)

# Running the hypothesis test

test_adder()

# %% [markdown]
# test_adder() ran without any issues so it's passed Hypothesis test suite. What about bad_adder()?

# %%
@given(st.integers(), st.integers())
def test_bad_adder(x, y):
    assert bad_adder(x, y) == operator.add(x, y)

# Running the hypothesis test

test_bad_adder()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[32], line 7
#       3     assert bad_adder(x, y) == operator.add(x, y)
#       5 # Running the hypothesis test
# ----> 7 test_bad_adder()
#
# Cell In[32], line 2, in test_bad_adder()
#       1 @given(st.integers(), st.integers())
# ----> 2 def test_bad_adder(x, y):
#       3     assert bad_adder(x, y) == operator.add(x, y)
#       5 # Running the hypothesis test
#
#     [... skipping hidden 1 frame]
#
# Cell In[32], line 3, in test_bad_adder(x, y)
#       1 @given(st.integers(), st.integers())
#       2 def test_bad_adder(x, y):
# ----> 3     assert bad_adder(x, y) == operator.add(x, y)
#
# AssertionError:
# Falsifying example: test_bad_adder(
#     x=1_000_000_001,
#     y=0,  # or any other generated value
# )
# Explanation:
#     These lines were always and only run by failing examples:
#         C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\413260956.py:10

# %% [markdown]
# ```
# Falsifying example: test_bad_adder(
#     x=1_000_000_001,
#     y=0,  # or any other generated value
# )
# Explanation:
#     These lines were always and only run by failing examples:
# ```
#
# Wow we see that Hypothesis is telling us that the test fails for any value of y where x is 1_000_000_001 (underlines have no semantic meaning it's just for ease of reading).
#
# How did Hypothesis figure this out? Let's look under the hood. To do this we can set the Verbosity setting to explicitly mention all the combinations of inputs it's trying:

# %%
from hypothesis._settings import Verbosity

@given(st.integers(), st.integers())
@settings(verbosity=Verbosity.verbose)
def test_bad_adder(x, y):
    assert bad_adder(x, y) == operator.add(x, y)

# Running the hypothesis test

test_bad_adder()
# Out:
# Trying example: test_bad_adder(
#     x=0,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=11220,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=11220,
#     y=-125,
# )
# Trying example: test_bad_adder(
#     x=-25356,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-25356,
#     y=1_460_961_168,
# )
# Trying example: test_bad_adder(
#     x=7801,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=7801,
#     y=-365,
# )
# Trying example: test_bad_adder(
#     x=17134,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=17134,
#     y=-19139,
# )
# Trying example: test_bad_adder(
#     x=-1_750_728_349,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-1_750_728_349,
#     y=7298,
# )
# Trying example: test_bad_adder(
#     x=7298,
#     y=7298,
# )
# Trying example: test_bad_adder(
#     x=-6097,
#     y=9598,
# )
# Trying example: test_bad_adder(
#     x=-6097,
#     y=-6097,
# )
# Trying example: test_bad_adder(
#     x=-21,
#     y=27,
# )
# Trying example: test_bad_adder(
#     x=27,
#     y=27,
# )
# Trying example: test_bad_adder(
#     x=11925,
#     y=-61,
# )
# Trying example: test_bad_adder(
#     x=-61,
#     y=-61,
# )
# Trying example: test_bad_adder(
#     x=-15245,
#     y=-106,
# )
# Trying example: test_bad_adder(
#     x=-106,
#     y=-106,
# )
# Trying example: test_bad_adder(
#     x=-12712,
#     y=-1953,
# )
# Trying example: test_bad_adder(
#     x=-1953,
#     y=-1953,
# )
# Trying example: test_bad_adder(
#     x=-16300,
#     y=-19296,
# )
# Trying example: test_bad_adder(
#     x=-16300,
#     y=-16300,
# )
# Trying example: test_bad_adder(
#     x=-28069,
#     y=13354,
# )
# Trying example: test_bad_adder(
#     x=-28069,
#     y=-28069,
# )
# Trying example: test_bad_adder(
#     x=5332,
#     y=-66,
# )
# Trying example: test_bad_adder(
#     x=-66,
#     y=-66,
# )
# Trying example: test_bad_adder(
#     x=-1745,
#     y=-25009,
# )
# Trying example: test_bad_adder(
#     x=-1745,
#     y=-1745,
# )
# Trying example: test_bad_adder(
#     x=-26043,
#     y=28767,
# )
# Trying example: test_bad_adder(
#     x=-26043,
#     y=-26043,
# )
# Trying example: test_bad_adder(
#     x=-7379,
#     y=-7_553_345_852_003_845_556,
# )
# Trying example: test_bad_adder(
#     x=-7_553_345_852_003_845_556,
#     y=-7_553_345_852_003_845_556,
# )
# Trying example: test_bad_adder(
#     x=80,
#     y=14031,
# )
# Trying example: test_bad_adder(
#     x=14031,
#     y=14031,
# )
# Trying example: test_bad_adder(
#     x=-24,
#     y=-8_557_663_281_701_062_348,
# )
# Trying example: test_bad_adder(
#     x=-8_557_663_281_701_062_348,
#     y=-8_557_663_281_701_062_348,
# )
# Trying example: test_bad_adder(
#     x=1_253_255_762,
#     y=13489,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_253_255_762,
#     y=1_253_255_762,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=-25900,
#     y=-29246,
# )
# Trying example: test_bad_adder(
#     x=-29246,
#     y=-29246,
# )
# Trying example: test_bad_adder(
#     x=-6_402_468_781_698_315_705,
#     y=20529,
# )
# Trying example: test_bad_adder(
#     x=-6_402_468_781_698_315_705,
#     y=-6_402_468_781_698_315_705,
# )
# Trying example: test_bad_adder(
#     x=-7_181_861_799_384_304_058,
#     y=-23479,
# )
# Trying example: test_bad_adder(
#     x=-7_181_861_799_384_304_058,
#     y=-7_181_861_799_384_304_058,
# )
# Trying example: test_bad_adder(
#     x=11727,
#     y=744026562,
# )
# Trying example: test_bad_adder(
#     x=11727,
#     y=11727,
# )
# Trying example: test_bad_adder(
#     x=30683,
#     y=-23819,
# )
# Trying example: test_bad_adder(
#     x=30683,
#     y=30683,
# )
# Trying example: test_bad_adder(
#     x=9_222_756_639_597_245_656,
#     y=-38,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=9_222_756_639_597_245_656,
#     y=9_222_756_639_597_245_656,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=127,
#     y=5075,
# )
# Trying example: test_bad_adder(
#     x=127,
#     y=127,
# )
# Trying example: test_bad_adder(
#     x=-58_502_647_654_077_514_080_673_818_917_181_234_365,
#     y=22204,
# )
# Trying example: test_bad_adder(
#     x=22204,
#     y=22204,
# )
# Trying example: test_bad_adder(
#     x=4068,
#     y=-3238,
# )
# Trying example: test_bad_adder(
#     x=4068,
#     y=4068,
# )
# Trying example: test_bad_adder(
#     x=79,
#     y=-19617,
# )
# Trying example: test_bad_adder(
#     x=-19617,
#     y=-19617,
# )
# Trying example: test_bad_adder(
#     x=15991,
#     y=-2253,
# )
# Trying example: test_bad_adder(
#     x=-2253,
#     y=-2253,
# )
# Trying example: test_bad_adder(
#     x=6431,
#     y=-76_601_853_562_978_601_459_230_336_069_775_433_584,
# )
# Trying example: test_bad_adder(
#     x=6431,
#     y=6431,
# )
# Trying example: test_bad_adder(
#     x=-14405,
#     y=-8,
# )
# Trying example: test_bad_adder(
#     x=-14405,
#     y=-14405,
# )
# Trying example: test_bad_adder(
#     x=119,
#     y=24714,
# )
# Trying example: test_bad_adder(
#     x=24714,
#     y=24714,
# )
# Trying example: test_bad_adder(
#     x=2_790_526_151_794_795_373,
#     y=-27667,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=2_790_526_151_794_795_373,
#     y=2_790_526_151_794_795_373,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=280322853,
#     y=115,
# )
# Trying example: test_bad_adder(
#     x=280322853,
#     y=280322853,
# )
# Trying example: test_bad_adder(
#     x=-13407,
#     y=2459,
# )
# Trying example: test_bad_adder(
#     x=2459,
#     y=2459,
# )
# Trying example: test_bad_adder(
#     x=-16,
#     y=28498,
# )
# Trying example: test_bad_adder(
#     x=-16,
#     y=-16,
# )
# Trying example: test_bad_adder(
#     x=1_286_433_157,
#     y=-56,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=-56,
#     y=-56,
# )
# Trying example: test_bad_adder(
#     x=1_286_433_157,
#     y=-56,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_157,
#     y=-56,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=-56,
#     y=1_286_433_157,
# )
# Trying example: test_bad_adder(
#     x=1_286_433_157,
#     y=56,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_157,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=212691333,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=153,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=133,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=643216578,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_286_433_155,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=212691331,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=131,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=643216577,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_286_433_153,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_151,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_149,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_147,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_145,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_135,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_115,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_433_075,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_432_995,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_432_835,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_432_515,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_431_875,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_430_595,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_428_035,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_422_915,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_412_675,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_392_195,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_351_235,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_269_315,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_286_105_475,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_285_777_795,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_285_122_435,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_283_811_715,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_281_190_275,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_275_947_395,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_265_461_635,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_244_490_115,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_202_547_075,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_118_660_995,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=950888835,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_034_774_915,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=992831875,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_013_803_395,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_003_317_635,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=998074755,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_000_696_195,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=999385475,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_000_040_835,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=999713155,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=999876995,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=999958915,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=999999875,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_000_020_355,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_010_115,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_004_995,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_002_435,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_001_155,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_515,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_195,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_035,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=999999955,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=999999995,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_000_000_015,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_005,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=999999999,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_000_000_000,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-1,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-212691331,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-153,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-131,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-643216577,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-1_286_433_153,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-1_286_433_154,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_286_433_154,
#     y=0,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=-212691333,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-133,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-643216578,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-1_286_433_155,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-1_286_433_156,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=463129089,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=238,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=500000000,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-463129089,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-238,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-500000000,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-999999999,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=-1_000_000_000,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=1_000_000_000,
#     y=1,
# )
# Trying example: test_bad_adder(
#     x=-59,
#     y=0,
# )
# Trying example: test_bad_adder(
#     x=0,
#     y=1_000_000_001,
# )
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=41,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-104_320_905_635_275_947_731_506_943_919_765_946_224,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-12,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-5,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-361871534,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=65,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-38,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=819387701,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=13425,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-87,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=3,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-99,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=29029,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-77,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=1,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=3498,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=17,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=10385,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=79,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=8357,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-1_608_056_285,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-101,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=62,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-2_499_394_880_718_885_216,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-5_620_416_568_432_106_851,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=1_868_985_778,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-1039,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-1_317_600_247,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=13521,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=13499,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=12,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=20252,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=97,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=9756,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-9749,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-668_363_353_424_139_827,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-62,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=63,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=79,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-13_054_202_954_180_920_621_287_306_604_995_427_666,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=129_667_008_566_969_579_712_267_450_400_840_244_073,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-73,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=3,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-12356,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-3040,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=15391,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-19482,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=30478,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=71,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=3_157_531_211_957_202_476,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=895_586_907_371_602_409,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-13,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=97,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=3827,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-18764,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=24416,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=375353410,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=16635,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=37_272_740_853_352_671_928_825_815_691_155_569_122,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-11,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-119,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-95_719_843_064_047_898,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=119,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-73,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=17841,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=9_037_303_675_108_838_489,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=14,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-7430,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-7_727_267_481_563_036_508,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=5_009_855_245_785_885_280,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-5997,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=11014,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-73,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=1_029_251_554,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-76_343_112_777_912_779_005_741_798_516_967_197_613,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-24998,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-13565,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-62,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-127,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=27,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-114,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-2743,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-24,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-693,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=2_020_509_365,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=28653,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-23325,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=29061,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-1_387_130_800,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=19601,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-13785,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-72,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-5368,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=8727,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=5731,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-13101,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=7446,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=-1450,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=9070,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
#
# Trying example: test_bad_adder(
#     x=1_000_000_001,
#     y=102_257_224_861_474_055_986_069_501_557_717_224_408,
# )
# Traceback (most recent call last):
#   File "C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3035993873.py", line 6, in test_bad_adder
#     assert bad_adder(x, y) == operator.add(x, y)
# AssertionError
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[37], line 10
#       6     assert bad_adder(x, y) == operator.add(x, y)
#       8 # Running the hypothesis test
# ---> 10 test_bad_adder()
#
# Cell In[37], line 4, in test_bad_adder()
#       1 from hypothesis._settings import Verbosity
#       3 @given(st.integers(), st.integers())
# ----> 4 @settings(verbosity=Verbosity.verbose)
#       5 def test_bad_adder(x, y):
#       6     assert bad_adder(x, y) == operator.add(x, y)
#       8 # Running the hypothesis test
#
#     [... skipping hidden 1 frame]
#
# Cell In[37], line 6, in test_bad_adder(x, y)
#       3 @given(st.integers(), st.integers())
#       4 @settings(verbosity=Verbosity.verbose)
#       5 def test_bad_adder(x, y):
# ----> 6     assert bad_adder(x, y) == operator.add(x, y)
#
# AssertionError:
# Falsifying example: test_bad_adder(
#     x=1_000_000_001,
#     y=0,  # or any other generated value
# )
# Explanation:
#     These lines were always and only run by failing examples:
#         C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\413260956.py:10

# %% [markdown]
# Looking at logs, see how Hypothesis tried many combinations of inputs before it stumbled on one where x=1_000_000_001. The real magic is that it doesn't stop there. After it realises there was something wrong witht that case, it tries many combinations of y values to "shrink" the problematic example down to what we see in the final AssertionError of the block. That's how it knows the problem is the x value regardless of y value.
#
# This "shrinking" means you, the developer, don't have to spend time figuring whether the bug you're seeing appears only in a specific cases or when a combination of conditions are met. Hypothesis finds out for you!
# ```
# Falsifying example: test_bad_adder(
#     x=1_000_000_001,
#     y=0,  # or any other generated value
# )
# Explanation:
#     These lines were always and only run by failing examples:
# ```
#
# You can probably guess what's wrong with bad_adder():

# %%
def bad_adder(x, y):
    if x>1000000000:
        return  "1; DROP TABLE users;"
    else:
        return x + y

# %% [markdown]
# # Test anything you can imagine!

# %% [markdown]
# Hypothesis has a huge range of built in strategies for almost any primitive, and even complex, types! There's a couple of really convenient ones too for urls, emails, and ip addresses, which are hard for people to think of edge cases for.

# %%
from hypothesis import strategies as st

# Define various strategies
int_strategy = st.integers(min_value=0, max_value=100)
float_strategy = st.floats(min_value=0.0, max_value=100.0)
text_strategy = st.text(min_size=1, max_size=10)
bool_strategy = st.booleans()
date_strategy = st.dates()
datetime_strategy = st.datetimes()
time_strategy = st.times()
timedelta_strategy = st.timedeltas()
complex_strategy = st.complex_numbers()
decimal_strategy = st.decimals(min_value=0, max_value=100)
none_strategy = st.none()
just_strategy = st.just("fixed value")  # Always produces "fixed value"
sampled_from_strategy = st.sampled_from(["apple", "banana", "cherry"])
binary_strategy = st.binary(min_size=1, max_size=10)
uuid_strategy = st.uuids()
email_strategy = st.emails()
ipv4_strategy = st.ip_addresses(v=4)
ipv6_strategy = st.ip_addresses(v=6)

# Generate and print examples
print("Integer example:", int_strategy.example())
print("Float example:", float_strategy.example())
print("Text example:", text_strategy.example())
print("Boolean example:", bool_strategy.example())
print("Date example:", date_strategy.example())
print("Datetime example:", datetime_strategy.example())
print("Time example:", time_strategy.example())
print("Timedelta example:", timedelta_strategy.example())
print("Complex number example:", complex_strategy.example())
print("Decimal example:", decimal_strategy.example())
print("None example:", none_strategy.example())
print("Just example:", just_strategy.example())
print("Sampled from example:", sampled_from_strategy.example())
print("Binary example:", binary_strategy.example())
print("UUID example:", uuid_strategy.example())
print("Email example:", email_strategy.example())
print("IPv4 address example:", ipv4_strategy.example())
print("IPv6 address example:", ipv6_strategy.example())
# Out:
# Integer example: 88
# Float example: 33.79056145331117
# Text example: ë򹑡j^򬎼
# Boolean example: False
# Date example: 0690-08-31
# Datetime example: 2925-11-16 16:05:21.592163
# Time example: 16:22:03.196605
# Timedelta example: 145598379 days, 17:32:18.413526
# Complex number example: (-1.1754943508222875e-38-1.1754943508222875e-38j)
# Decimal example: 25.446075067
# None example: None
# Just example: fixed value
# Sampled from example: banana
# Binary example: b':\xc2\xf1\x16\\P\xbfJQ8'
# UUID example: 79c0f8f7-bd8a-cbc6-cb6c-7dc0c0c74989
# Email example: YfM%@Q.N.N.JaVa
# IPv4 address example: 192.0.0.171
# IPv6 address example: fe80::8f1b

# %% [markdown]
# You might be thinking how about data structures as examples, like creating a list to pass into a merge sort? For those Hypothesis has composite structures, you can combine different strategies together to create the data structure and format you want.
#
# This example produces a lists between length 1 and 10 that are made of integers:

# %%
list_strategy = st.lists(st.integers(), min_size=1, max_size=10)
print("List example:", list_strategy.example())
# Out:
# List example: [30688, 15777, -4025, 30688, 1249, -8460, 14622, -6309, 1281364988, 54031598197614973]

# %% [markdown]
# We can do the same for other data structures:

# %%
# Composite structures
tuple_strategy = st.tuples(st.integers(), st.text(min_size=1, max_size=5))
set_strategy = st.sets(st.integers(), min_size=1, max_size=5)
dict_strategy = st.dictionaries(keys=st.text(min_size=1, max_size=5), values=st.integers(min_value=0, max_value=100))
frozenset_strategy = st.frozensets(st.integers(), min_size=1, max_size=5)

# Recursive structures (useful for generating nested structures)
nested_list_strategy = st.recursive(st.integers(), lambda children: st.lists(children, min_size=1, max_size=3))

print("Tuple example:", tuple_strategy.example())
print("Set example:", set_strategy.example())
print("Dictionary example:", dict_strategy.example())
print("Frozenset example:", frozenset_strategy.example())
print("Nested list example:", nested_list_strategy.example())
# Out:
# Tuple example: (-31622, '$')
# Set example: {0, -7479, -12427}
# Dictionary example: {'\x9dÔ°': 12, 'î9\U000c025b¦': 75, 'C\U000fa6e9+CÀ': 81, 'w¥0': 11}
# Frozenset example: frozenset({-12040, -32295, 24092, -29076})
# Nested list example: [[[107], [8388, 30211, 30211], 80], -106493887758229762873977497755043716652, 19]

# %% [markdown]
# One really useful application of this is creating json objects for testing APIs, these are far too tedious to write by hand especially for json objects with many fields. With hypothesis it's trivial:

# %%
from hypothesis import strategies as st

EcommerceData = st.fixed_dictionaries(
    {
        "product": st.fixed_dictionaries(
            {
                "product_id": st.text(min_size=8, max_size=12),  # Unique identifier for the product
                "name": st.text(min_size=5, max_size=50),  # Product name
                "category": st.sampled_from(
                    ["electronics", "clothing", "home", "toys", "books", "beauty", "sports", "automotive"]
                ),
                "price": st.floats(min_value=0.0, max_value=1000.0),  # Price of the product
                "discount": st.one_of(st.none(), st.floats(min_value=0.0, max_value=0.5)),  # Discount rate (0-50%)
                "in_stock": st.integers(min_value=0, max_value=1000),  # Quantity available in stock
            }
        ),
        "user": st.fixed_dictionaries(
            {
                "user_id": st.text(min_size=8, max_size=12),  # Unique user ID
                "username": st.text(min_size=5, max_size=15),  # Username
                "email": st.emails(),  # User email
                "is_premium_member": st.booleans(),  # Whether the user has a premium membership
                "age": st.one_of(st.none(), st.integers(min_value=18, max_value=80)),  # Age of the user
                "address": st.fixed_dictionaries(
                    {
                        "street": st.text(min_size=10, max_size=100),
                        "city": st.text(min_size=3, max_size=50),
                        "zip_code": st.text(min_size=5, max_size=10),
                        "country": st.sampled_from(["US", "CA", "GB", "AU", "DE", "FR"]),
                    }
                ),
            }
        ),
        "order": st.fixed_dictionaries(
            {
                "order_id": st.text(min_size=8, max_size=12),  # Unique order identifier
                "order_date": st.datetimes(),  # Date and time of order
                "status": st.sampled_from(["pending", "shipped", "delivered", "canceled", "returned"]),
                "items": st.lists(
                    st.fixed_dictionaries(
                        {
                            "product_id": st.text(min_size=8, max_size=12),
                            "quantity": st.integers(min_value=1, max_value=5),  # Quantity of each item
                            "price": st.floats(min_value=0.0, max_value=1000.0),  # Price per item
                        }
                    ),
                    min_size=1,
                    max_size=5,
                ),
                "total_cost": st.floats(min_value=0.0, max_value=5000.0),  # Total cost of the order
                "payment_method": st.sampled_from(["credit_card", "paypal", "gift_card", "crypto"]),
                "shipping_address": st.one_of(st.none(), st.text(min_size=10, max_size=200)),
            }
        ),
    }
)

# Generate and print an example
EcommerceData.example()
# Out:
# {'product': {'product_id': '\U0003893a\U0008d80bK+\x89à¾Vf\x04\x0e&',
#   'name': '\U0002fe00\U00078d56[X\U0007cbcaDTË\x08\x97KòD\U000192b8\x80\x9eU',
#   'category': 'electronics',
#   'price': 999.9999999999999,
#   'discount': 5.960464477539063e-08,
#   'in_stock': 947},
#  'user': {'user_id': '\x0f}\x9e^\x94æ+\x98½\x1aûÉ',
#   'username': '\xa0®ô4忎\x85;ëð',
#   'email': 'mVi0L51@uuOO.phIlIPs',
#   'is_premium_member': True,
#   'age': 60,
#   'address': {'street': '\U0009e179¦ë?\x0e겇¤\U000975d8\x94\U0004051c𰧯©',
#    'city': '\x0eü4ê𡛺]\U000a892d\U000daaef(=ö.q\x18\U0003c375\x7fÿ\x88ÕÕ{',
#    'zip_code': '\U0003893a\U0008d80bK+\x89à¾Vf\x04',
#    'country': 'FR'}},
#  'order': {'order_id': '\x87£\x18{§E\U000400614\x14',
#   'order_date': datetime.datetime(8488, 7, 10, 14, 16, 18, 283187, fold=1),
#   'status': 'returned',
#   'items': [{'product_id': 'Ïä\x1e\U000b2864DXã+CnÓ{',
#     'quantity': 1,
#     'price': 2.225073858507e-311},
#    {'product_id': 'Ïä\x1e\U000b2864DXã+CnÓ{',
#     'quantity': 1,
#     'price': 2.225073858507e-311}],
#   'total_cost': 0.0,
#   'payment_method': 'credit_card',
#   'shipping_address': None}}

# %% [markdown]
# The data might look like gibberish, but that's the point! We want to make sure the thing we're testing performs as expected given data that meets it's specficiations. So the API should be able to handle it gracefully!

# %% [markdown]
# # Hypothesis can write test functions for you!
#
# Before we saw that hypothesis removes having to think about what specific inputs to test. But Hypothesis can also write the *test functions* for you!
#
# Hypothesis has a set of *ghostwriters* that help you write common forms of test functions. For example there is the *fuzz* ghostwriter that helps you write a test function that ensures that if a function is given a valid input, it will always give an expected result (i.e., no errors or only accepted errors):

# %%
from hypothesis.extra import ghostwriter


def adder(x, y):
    return x + y
    
print(ghostwriter.fuzz(adder))
# Out:
# # This test code was written by the `hypothesis.extra.ghostwriter` module
# # and is provided under the Creative Commons Zero public domain dedication.
#
# from hypothesis import given, strategies as st
#
# # TODO: replace st.nothing() with appropriate strategies
#
#
# @given(x=st.nothing(), y=st.nothing())
# def test_fuzz_adder(x, y):
#     adder(x=x, y=y)

# %% [markdown]
# Noticed the test function's decorator uses the placeholder strategy st.nothing(), this is because Hypothesis cannot infer what types the arguments should be given Python isn't a strongly typed language.
#
# To help Hypothesis auto choose the right strategies, simply add a type signature to your function:

# %%
def adder(x: int, y: int) -> int:
    return x + y
    
print(ghostwriter.fuzz(adder))
# Out:
# # This test code was written by the `hypothesis.extra.ghostwriter` module
# # and is provided under the Creative Commons Zero public domain dedication.
#
# from hypothesis import given, strategies as st
#
#
# @given(x=st.integers(), y=st.integers())
# def test_fuzz_adder(x: int, y: int) -> None:
#     adder(x=x, y=y)

# %% [markdown]
# Now Hypothesis has automatically chosen the the right strategies to use and you've a ready-made test function!
#
# There are other ghostwriters too! Two useful ones are idempotent() and roundtrip():
#
# idempotent() checks whether *f*(a) == *f*(*f*(a)), e.g., in the case of sorting algorithmns, sorting an already sorted array should yield that original array without any changes:

# %%
print(ghostwriter.idempotent(sorted))
# Out:
# # This test code was written by the `hypothesis.extra.ghostwriter` module
# # and is provided under the Creative Commons Zero public domain dedication.
#
# from hypothesis import given, strategies as st
#
#
# @given(
#     iterable=st.one_of(st.iterables(st.integers()), st.iterables(st.text())),
#     key=st.none(),
#     reverse=st.booleans(),
# )
# def test_idempotent_sorted(iterable, key, reverse):
#     result = sorted(iterable, key=key, reverse=reverse)
#     repeat = sorted(result, key=key, reverse=reverse)
#     assert result == repeat, (result, repeat)

# %% [markdown]
# Here we're asking Hypothesis to create a test function for Python's built-in sorting function. Notice is applied strategies for all the arguments of sorted(): iterable (the list of integers or strings you want to sort), key (which is always none), and reverse (a bool that determines ascending or descending order):

# %%
@given(
    iterable=st.one_of(st.iterables(st.integers()), st.iterables(st.text())),
    key=st.none(),
    reverse=st.booleans(),
)
@settings(verbosity=Verbosity.verbose)
def test_idempotent_sorted(iterable, key, reverse):
    result = sorted(iterable, key=key, reverse=reverse)
    repeat = sorted(result, key=key, reverse=reverse)
    assert result == repeat, (result, repeat)

test_idempotent_sorted()
# Out:
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([]),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([]),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([0]),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([24594, 5823]),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([]),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(["'"]),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['\U0006826dÿ|\U0004bebe\U000a67a1']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([58]),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['', '']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['', 'à', 'C']),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['', 'C', 'C']),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['C', 'C', 'C']),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ü\x02T',
#          '2',
#          'ë\U000711d5\U000d4b2d]UlK',
#          'E³\U000459de\U00019afe2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'k',
#          '\tb',
#          '\U000dde2f_',
#          '\xad',
#          '',
#          '\x87ôå\U000fe6b9',
#          'É©\U000fb6d2~',
#          'õB82',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤',
#          ''],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ü\x02T',
#          '2',
#          'ë\U000711d5\U000d4b2d]UlK',
#          'E³\U000459de\U00019afe2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'k',
#          '\tb',
#          '\U000dde2f_',
#          '\xad',
#          '',
#          '\x87ôå\U000fe6b9',
#          'É©\U000fb6d2~',
#          'õB82',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ü\x02T',
#          '2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'E³\U000459de\U00019afe2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'k',
#          '\tb',
#          '\U000dde2f_',
#          '\xad',
#          '',
#          '\x87ôå\U000fe6b9',
#          'É©\U000fb6d2~',
#          'õB82',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ü\x02T',
#          '2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'õB82',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'k',
#          '\tb',
#          '\U000dde2f_',
#          '\xad',
#          '',
#          '\x87ôå\U000fe6b9',
#          'É©\U000fb6d2~',
#          'õB82',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ü\x02T',
#          '2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'õB82',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'k',
#          '\tb',
#          '\U000dde2f_',
#          '\xad',
#          '',
#          '2',
#          'É©\U000fb6d2~',
#          'õB82',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ü\x02T',
#          '2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'õB82',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'k',
#          '\tb',
#          '2',
#          '\xad',
#          '',
#          '2',
#          'É©\U000fb6d2~',
#          'õB82',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['tD\x957\U000b7a8b𠴅q\x18',
#          '2',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'õB82',
#          'tD\x957\U000b7a8b𠴅q\x18',
#          'k',
#          '\tb',
#          '2',
#          '\xad',
#          '',
#          '2',
#          'É©\U000fb6d2~',
#          'õB82',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤',
#          '¦à¨\U0003d1f0÷ï?\x89½À¹s\U00039780L\x18)\x99G\x9fA\x10¤'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([22720]),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-2780,
#          -27694,
#          8_768_025_409_152_680_990,
#          10163,
#          68,
#          -96,
#          25034,
#          -1_432_570_792,
#          17018,
#          -13688],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-2780,
#          -27694,
#          25034,
#          10163,
#          68,
#          -96,
#          25034,
#          -1_432_570_792,
#          17018,
#          -13688],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-13688,
#          -27694,
#          25034,
#          10163,
#          68,
#          -96,
#          25034,
#          -1_432_570_792,
#          17018,
#          -13688],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-13688, -27694, 25034, 10163, 68, -96, 25034, -13688, 17018, -13688],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-13688, -27694, 25034, 68, 68, -96, 25034, -13688, 17018, -13688],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-13688, -27694, 25034, 68, 68, -96, -27694, -13688, 17018, -13688],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-13688, -27694, -13688, 68, 68, -96, -27694, -13688, 17018, -13688],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([]),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['A*N\x96Y©\U00070d59', '\U000ad317']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['\U000ad317', '\U000ad317']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['\U000ad317']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [8_831_365_666_323_660_764,
#          -21445,
#          -139031846,
#          -23088,
#          12476,
#          7,
#          -2849],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [8_831_365_666_323_660_764, -21445, 12476, -23088, 12476, 7, -2849],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [8_831_365_666_323_660_764,
#          -21445,
#          12476,
#          -23088,
#          12476,
#          7,
#          8_831_365_666_323_660_764],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [8_831_365_666_323_660_764, -21445, 12476, -23088, 12476, 7, 12476],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([12476, -21445, 12476, -23088, 12476, 7, 12476]),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([12476, -21445, 12476, 12476, 12476, 7, 12476]),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['Ù',
#          '\U0005f444Ö?ö\x07ær\U00064572\x89\x82\U0008b06d<\x1a9',
#          'æ',
#          ''],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['Ù', 'Ù', 'æ', '']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['Ù', 'Ù']),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ä\U000ecd47',
#          '\xad|Cü',
#          '\xad²',
#          '',
#          'Ç',
#          '"U \x07È\U00050edb\U0009eee5\'J`\x9c\x0e',
#          '\x86A\x91\U000c2f57ú\U00044007\U0008814a\x841)à',
#          '',
#          '¶\U000c078c,',
#          '\U000f7e26\U000aed79\U000b8879Á\U0006282dí',
#          '\x0f',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ'],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ä\U000ecd47',
#          '\xad|Cü',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ',
#          '',
#          'Ç',
#          '"U \x07È\U00050edb\U0009eee5\'J`\x9c\x0e',
#          '\x86A\x91\U000c2f57ú\U00044007\U0008814a\x841)à',
#          '',
#          '¶\U000c078c,',
#          '\U000f7e26\U000aed79\U000b8879Á\U0006282dí',
#          '\x0f',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ'],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ä\U000ecd47',
#          '\xad|Cü',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ',
#          '',
#          '¶\U000c078c,',
#          '"U \x07È\U00050edb\U0009eee5\'J`\x9c\x0e',
#          '\x86A\x91\U000c2f57ú\U00044007\U0008814a\x841)à',
#          '',
#          '¶\U000c078c,',
#          '\U000f7e26\U000aed79\U000b8879Á\U0006282dí',
#          '\x0f',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ'],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['ä\U000ecd47',
#          '\xad|Cü',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ',
#          '',
#          '¶\U000c078c,',
#          '"U \x07È\U00050edb\U0009eee5\'J`\x9c\x0e',
#          '\x86A\x91\U000c2f57ú\U00044007\U0008814a\x841)à',
#          '',
#          '¶\U000c078c,',
#          '\U000f7e26\U000aed79\U000b8879Á\U0006282dí',
#          '¶\U000c078c,',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ'],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          '\xad|Cü',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ',
#          '',
#          '¶\U000c078c,',
#          '"U \x07È\U00050edb\U0009eee5\'J`\x9c\x0e',
#          '\x86A\x91\U000c2f57ú\U00044007\U0008814a\x841)à',
#          '',
#          '¶\U000c078c,',
#          '\U000f7e26\U000aed79\U000b8879Á\U0006282dí',
#          '¶\U000c078c,',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ'],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['¶\U000c078c,',
#          '\xad|Cü',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ',
#          '',
#          '¶\U000c078c,',
#          '"U \x07È\U00050edb\U0009eee5\'J`\x9c\x0e',
#          '\x86A\x91\U000c2f57ú\U00044007\U0008814a\x841)à',
#          '',
#          '¶\U000c078c,',
#          '\U000f7e26\U000aed79\U000b8879Á\U0006282dí',
#          '¶\U000c078c,',
#          '\U001029db\U000b8bf4\x96ÕF\x89흇õ\x1fQ'],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['\x9d[\U0008b006\x99\U00046fecW\U000d8535W{á\U000dabe9\x8b\x92',
#          'j\U000b6a1fò',
#          'Ù\U0001256a&ê³n\U00056c92',
#          '',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          '',
#          '\U000b833bùꎇ'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['\x9d[\U0008b006\x99\U00046fecW\U000d8535W{á\U000dabe9\x8b\x92',
#          'j\U000b6a1fò',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          '',
#          '\U000b833bùꎇ'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['\x9d[\U0008b006\x99\U00046fecW\U000d8535W{á\U000dabe9\x8b\x92',
#          '',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          '',
#          '\U000b833bùꎇ'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          '',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          '',
#          '\U000b833bùꎇ'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          '',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          'ú\rì',
#          '',
#          '\U000b833bùꎇ'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          '',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          'ú\rì',
#          '',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          '',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          'ú\rì',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛',
#          '[\U000e7058w𦖂Ö\U00046fe8/\x1b\U00045b65𨊵퍛'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-15558,
#          6336,
#          -66,
#          -22120,
#          -51,
#          11656,
#          16820,
#          -1307,
#          -96209158,
#          23307,
#          70_070_369_973_734_287_789_605_517_020_071_097_572],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [70_070_369_973_734_287_789_605_517_020_071_097_572,
#          6336,
#          -66,
#          -22120,
#          -51,
#          11656,
#          16820,
#          -1307,
#          -96209158,
#          23307,
#          70_070_369_973_734_287_789_605_517_020_071_097_572],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [70_070_369_973_734_287_789_605_517_020_071_097_572,
#          6336,
#          -66,
#          -22120,
#          -51,
#          11656,
#          16820,
#          23307,
#          -96209158,
#          23307,
#          70_070_369_973_734_287_789_605_517_020_071_097_572],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [70_070_369_973_734_287_789_605_517_020_071_097_572,
#          6336,
#          -66,
#          -22120,
#          -96209158,
#          11656,
#          16820,
#          23307,
#          -96209158,
#          23307,
#          70_070_369_973_734_287_789_605_517_020_071_097_572],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [70_070_369_973_734_287_789_605_517_020_071_097_572,
#          6336,
#          -66,
#          -22120,
#          -96209158,
#          11656,
#          16820,
#          23307,
#          23307,
#          23307,
#          70_070_369_973_734_287_789_605_517_020_071_097_572],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [70_070_369_973_734_287_789_605_517_020_071_097_572,
#          6336,
#          -66,
#          -22120,
#          -96209158,
#          11656,
#          16820,
#          23307,
#          23307,
#          23307,
#          23307],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [70_070_369_973_734_287_789_605_517_020_071_097_572,
#          6336,
#          11656,
#          -22120,
#          -96209158,
#          11656,
#          16820,
#          23307,
#          23307,
#          23307,
#          23307],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          'Y\x10\x02\U0008efe7',
#          '',
#          '\x86jí\x0b',
#          '\x96\x9e\U0005d9cb/PT',
#          'Ç³\x13×𩌟\x16L',
#          '³Þ\U000855a9>',
#          '',
#          '\x0bþ=퀰}',
#          'äU¶\x11h¥𧢱\U000e83d3\x03',
#          '½£\U00108d43',
#          '\x8d\U0009186fí*\U000bb2bfYSçgªu&',
#          'L\x90Hªµ\U0005a9df',
#          '',
#          'Á<\U000ef7f8',
#          'à\U000b9114\x87´Ó¸\U000d4048\U000e4b1a\U00015030ú',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          '\U00063ec5\x0f',
#          '\x0fã',
#          '>\U0001c014\x1a즊\tï\U000420bc\x1a&©Ú\U000deb62\x80¼\x99W🌒¦\x7f\x92\U0003e41c?\x97\x8dë'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          'Y\x10\x02\U0008efe7',
#          '',
#          '\x86jí\x0b',
#          '\x96\x9e\U0005d9cb/PT',
#          'Ç³\x13×𩌟\x16L',
#          '³Þ\U000855a9>',
#          '³Þ\U000855a9>',
#          '\x0bþ=퀰}',
#          'äU¶\x11h¥𧢱\U000e83d3\x03',
#          '½£\U00108d43',
#          '\x8d\U0009186fí*\U000bb2bfYSçgªu&',
#          'L\x90Hªµ\U0005a9df',
#          '',
#          'Á<\U000ef7f8',
#          'à\U000b9114\x87´Ó¸\U000d4048\U000e4b1a\U00015030ú',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          '\U00063ec5\x0f',
#          '\x0fã',
#          '>\U0001c014\x1a즊\tï\U000420bc\x1a&©Ú\U000deb62\x80¼\x99W🌒¦\x7f\x92\U0003e41c?\x97\x8dë'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          'Y\x10\x02\U0008efe7',
#          '',
#          'L\x90Hªµ\U0005a9df',
#          '\x96\x9e\U0005d9cb/PT',
#          'Ç³\x13×𩌟\x16L',
#          '³Þ\U000855a9>',
#          '³Þ\U000855a9>',
#          '\x0bþ=퀰}',
#          'äU¶\x11h¥𧢱\U000e83d3\x03',
#          '½£\U00108d43',
#          '\x8d\U0009186fí*\U000bb2bfYSçgªu&',
#          'L\x90Hªµ\U0005a9df',
#          '',
#          'Á<\U000ef7f8',
#          'à\U000b9114\x87´Ó¸\U000d4048\U000e4b1a\U00015030ú',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          '\U00063ec5\x0f',
#          '\x0fã',
#          '>\U0001c014\x1a즊\tï\U000420bc\x1a&©Ú\U000deb62\x80¼\x99W🌒¦\x7f\x92\U0003e41c?\x97\x8dë'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          'Y\x10\x02\U0008efe7',
#          '',
#          'L\x90Hªµ\U0005a9df',
#          '\x96\x9e\U0005d9cb/PT',
#          'Ç³\x13×𩌟\x16L',
#          '³Þ\U000855a9>',
#          '³Þ\U000855a9>',
#          'Y\x10\x02\U0008efe7',
#          'äU¶\x11h¥𧢱\U000e83d3\x03',
#          '½£\U00108d43',
#          '\x8d\U0009186fí*\U000bb2bfYSçgªu&',
#          'L\x90Hªµ\U0005a9df',
#          '',
#          'Á<\U000ef7f8',
#          'à\U000b9114\x87´Ó¸\U000d4048\U000e4b1a\U00015030ú',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          '\U00063ec5\x0f',
#          '\x0fã',
#          '>\U0001c014\x1a즊\tï\U000420bc\x1a&©Ú\U000deb62\x80¼\x99W🌒¦\x7f\x92\U0003e41c?\x97\x8dë'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          'Y\x10\x02\U0008efe7',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          'L\x90Hªµ\U0005a9df',
#          '\x96\x9e\U0005d9cb/PT',
#          'Ç³\x13×𩌟\x16L',
#          '³Þ\U000855a9>',
#          '³Þ\U000855a9>',
#          'Y\x10\x02\U0008efe7',
#          'äU¶\x11h¥𧢱\U000e83d3\x03',
#          '½£\U00108d43',
#          '\x8d\U0009186fí*\U000bb2bfYSçgªu&',
#          'L\x90Hªµ\U0005a9df',
#          '',
#          'Á<\U000ef7f8',
#          'à\U000b9114\x87´Ó¸\U000d4048\U000e4b1a\U00015030ú',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          '\U00063ec5\x0f',
#          '\x0fã',
#          '>\U0001c014\x1a즊\tï\U000420bc\x1a&©Ú\U000deb62\x80¼\x99W🌒¦\x7f\x92\U0003e41c?\x97\x8dë'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          'Y\x10\x02\U0008efe7',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          'L\x90Hªµ\U0005a9df',
#          '\x96\x9e\U0005d9cb/PT',
#          'Ç³\x13×𩌟\x16L',
#          'Y\x10\x02\U0008efe7',
#          '³Þ\U000855a9>',
#          'Y\x10\x02\U0008efe7',
#          'äU¶\x11h¥𧢱\U000e83d3\x03',
#          '½£\U00108d43',
#          '\x8d\U0009186fí*\U000bb2bfYSçgªu&',
#          'L\x90Hªµ\U0005a9df',
#          '',
#          'Á<\U000ef7f8',
#          'à\U000b9114\x87´Ó¸\U000d4048\U000e4b1a\U00015030ú',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          '\U00063ec5\x0f',
#          '\x0fã',
#          '>\U0001c014\x1a즊\tï\U000420bc\x1a&©Ú\U000deb62\x80¼\x99W🌒¦\x7f\x92\U0003e41c?\x97\x8dë'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['',
#          'Y\x10\x02\U0008efe7',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          'Y\x10\x02\U0008efe7',
#          '\x96\x9e\U0005d9cb/PT',
#          'Ç³\x13×𩌟\x16L',
#          'Y\x10\x02\U0008efe7',
#          '³Þ\U000855a9>',
#          'Y\x10\x02\U0008efe7',
#          'äU¶\x11h¥𧢱\U000e83d3\x03',
#          '½£\U00108d43',
#          '\x8d\U0009186fí*\U000bb2bfYSçgªu&',
#          'L\x90Hªµ\U0005a9df',
#          '',
#          'Á<\U000ef7f8',
#          'à\U000b9114\x87´Ó¸\U000d4048\U000e4b1a\U00015030ú',
#          '\U000468b2\U0005ddab½¾\U0010de64\U000c3a211JÕµ¢\U0007b810\\',
#          '\U00063ec5\x0f',
#          '\x0fã',
#          '>\U0001c014\x1a즊\tï\U000420bc\x1a&©Ú\U000deb62\x80¼\x99W🌒¦\x7f\x92\U0003e41c?\x97\x8dë'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [144_605_981_331_774_366_757_924_242_419_603_819_542,
#          -610727630,
#          29256,
#          23151,
#          45],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [144_605_981_331_774_366_757_924_242_419_603_819_542,
#          -610727630,
#          29256,
#          29256,
#          45],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [144_605_981_331_774_366_757_924_242_419_603_819_542,
#          29256,
#          29256,
#          29256,
#          45],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [144_605_981_331_774_366_757_924_242_419_603_819_542,
#          29256,
#          29256,
#          29256,
#          29256],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([29256, 29256, 29256, 29256, 29256]),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['½ü𦋧\x97Éó',
#          '}\U0005d102öz\x1a\\',
#          '\U000dbf9e5v',
#          '\x0c·\t\x04\U0003b0b5µ¢'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['½ü𦋧\x97Éó',
#          '}\U0005d102öz\x1a\\',
#          '½ü𦋧\x97Éó',
#          '\x0c·\t\x04\U0003b0b5µ¢'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['½ü𦋧\x97Éó', '}\U0005d102öz\x1a\\', '½ü𦋧\x97Éó', '½ü𦋧\x97Éó'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         ['}\U0005d102öz\x1a\\',
#          '}\U0005d102öz\x1a\\',
#          '½ü𦋧\x97Éó',
#          '½ü𦋧\x97Éó'],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-9913,
#          -1_613_896_175,
#          -60_238_790_410_747_222_145_947_539_910_085_257_482],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-60_238_790_410_747_222_145_947_539_910_085_257_482,
#          -1_613_896_175,
#          -60_238_790_410_747_222_145_947_539_910_085_257_482],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-60_238_790_410_747_222_145_947_539_910_085_257_482,
#          -60_238_790_410_747_222_145_947_539_910_085_257_482,
#          -60_238_790_410_747_222_145_947_539_910_085_257_482],
#     ),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter([-288_714_815_484_603_339]),
#     key=None,
#     reverse=True,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-482931008, 15610, -87, -20153, -30760, 1_391_519_647, -4914],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-482931008, 15610, -30760, -20153, -30760, 1_391_519_647, -4914],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-482931008, -482931008, -30760, -20153, -30760, 1_391_519_647, -4914],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-482931008, -482931008, -30760, -20153, -30760, -20153, -4914],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-20153, -482931008, -30760, -20153, -30760, -20153, -4914],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-20153, -482931008, -482931008, -20153, -30760, -20153, -4914],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [-20153, -482931008, -482931008, -20153, -482931008, -20153, -4914],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [2089,
#          -1161,
#          8633,
#          11_064_487_395_866_475_925_070_774_371_056_466_969,
#          37,
#          12410,
#          -1_532_882_842_413_039_977,
#          -12968,
#          -28819,
#          7_029_767_805_826_236_941,
#          -11276],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [2089,
#          -1161,
#          8633,
#          11_064_487_395_866_475_925_070_774_371_056_466_969,
#          37,
#          12410,
#          -1_532_882_842_413_039_977,
#          -12968,
#          -28819,
#          7_029_767_805_826_236_941,
#          2089],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [2089,
#          -1161,
#          8633,
#          11_064_487_395_866_475_925_070_774_371_056_466_969,
#          37,
#          12410,
#          -1_532_882_842_413_039_977,
#          8633,
#          -28819,
#          7_029_767_805_826_236_941,
#          2089],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [2089,
#          -1161,
#          2089,
#          11_064_487_395_866_475_925_070_774_371_056_466_969,
#          37,
#          12410,
#          -1_532_882_842_413_039_977,
#          8633,
#          -28819,
#          7_029_767_805_826_236_941,
#          2089],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [2089,
#          -1161,
#          -1_532_882_842_413_039_977,
#          11_064_487_395_866_475_925_070_774_371_056_466_969,
#          37,
#          12410,
#          -1_532_882_842_413_039_977,
#          8633,
#          -28819,
#          7_029_767_805_826_236_941,
#          2089],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [2089,
#          -1161,
#          -1_532_882_842_413_039_977,
#          11_064_487_395_866_475_925_070_774_371_056_466_969,
#          37,
#          2089,
#          -1_532_882_842_413_039_977,
#          8633,
#          -28819,
#          7_029_767_805_826_236_941,
#          2089],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(
#         [2089,
#          -1161,
#          -1_532_882_842_413_039_977,
#          2089,
#          37,
#          2089,
#          -1_532_882_842_413_039_977,
#          8633,
#          -28819,
#          7_029_767_805_826_236_941,
#          2089],
#     ),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['', '', '', '9Ç']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['', '9Ç', '', '9Ç']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['', '9Ç', '', '']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['', '9Ç', '9Ç', '']),
#     key=None,
#     reverse=False,
# )
# Trying example: test_idempotent_sorted(
#     iterable=PrettyIter(['9Ç', '9Ç', '9Ç', '']),
#     key=None,
#     reverse=False,
# )

# %% [markdown]
# As expected the built-in sort function is idempotent(). Lots of functions out there are expected to be idempotent and this is a way to write test functions for them accurately and quickly!
#
# The roundtrip() ghostwriter checks whether *f*(*g*(x)) = x. This is important for encode decode functions or anything else that should be perfectly reversible.
#
# Let's look at these simple Cesar encode and decode functions:

# %%
def encode(text: str, shift: int = 3) -> str:
    encoded_chars = [chr(ord(char) + shift) for char in text]
    return ''.join(encoded_chars)

def decode(text: str, shift: int = 3) -> str:
    decoded_chars = [chr(ord(char) - shift) for char in text]
    return ''.join(decoded_chars)

# %% [markdown]
# The cipher works by shifting each character by a certain number of places so for example:

# %%
encode('a', shift=3)
# Out:
# 'd'

# %% [markdown]
# So this function should have a roundtrip property:

# %%
decode(encode('a', shift=3), shift=3) == 'a'
# Out:
# True

# %% [markdown]
# Let's make sure this is acutally true by getting Hypothesis to ghostwrite the test function and running it:

# %%
print(ghostwriter.roundtrip(encode, decode))
# Out:
# # This test code was written by the `hypothesis.extra.ghostwriter` module
# # and is provided under the Creative Commons Zero public domain dedication.
#
# from hypothesis import given, strategies as st
#
#
# @given(shift=st.integers(), text=st.text())
# def test_roundtrip_encode_decode(shift: int, text: str) -> None:
#     value0 = encode(text=text, shift=shift)
#     value1 = decode(text=value0, shift=shift)
#     assert text == value1, (text, value1)

# %%
@given(shift=st.integers(), text=st.text())
def test_roundtrip_encode_decode(shift: int, text: str) -> None:
    value0 = encode(text=text, shift=shift)
    value1 = decode(text=value0, shift=shift)
    assert text == value1, (text, value1)

test_roundtrip_encode_decode()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 7
#       4     value1 = decode(text=value0, shift=shift)
#       5     assert text == value1, (text, value1)
# ----> 7 test_roundtrip_encode_decode()
#
# Cell In[65], line 2, in test_roundtrip_encode_decode()
#       1 @given(shift=st.integers(), text=st.text())
# ----> 2 def test_roundtrip_encode_decode(shift: int, text: str) -> None:
#       3     value0 = encode(text=text, shift=shift)
#       4     value1 = decode(text=value0, shift=shift)
#
#     [... skipping hidden 1 frame]
#
# Cell In[65], line 3, in test_roundtrip_encode_decode(shift, text)
#       1 @given(shift=st.integers(), text=st.text())
#       2 def test_roundtrip_encode_decode(shift: int, text: str) -> None:
# ----> 3     value0 = encode(text=text, shift=shift)
#       4     value1 = decode(text=value0, shift=shift)
#       5     assert text == value1, (text, value1)
#
# Cell In[62], line 2, in encode(text, shift)
#       1 def encode(text: str, shift: int = 3) -> str:
# ----> 2     encoded_chars = [chr(ord(char) + shift) for char in text]
#       3     return ''.join(encoded_chars)
#
# ValueError: chr() arg not in range(0x110000)
# Falsifying example: test_roundtrip_encode_decode(
#     shift=-49,
#     text='0',
# )

# %% [markdown]
# It looks like we've found out that shift cannot be => -49, but why?
#
# ```
# ValueError: chr() arg not in range(0x110000)
# Falsifying example: test_roundtrip_encode_decode(
#     shift=-49,
#     text='0',
# )
# ```

# %%
encode(text='0', shift=-49)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 encode(text='0', shift=-49)
#
# Cell In[62], line 2, in encode(text, shift)
#       1 def encode(text: str, shift: int = 3) -> str:
# ----> 2     encoded_chars = [chr(ord(char) + shift) for char in text]
#       3     return ''.join(encoded_chars)
#
# ValueError: chr() arg not in range(0x110000)

# %%
ord('0')
# Out:
# 48

# %% [markdown]
# It's because the number that repesents '0' in the Unicode set is 48. But 48 shift -49 gives us -1, which does not correspond to any Unicode character so char(-1) throws and error

# %%
chr(-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 chr(-1)
#
# ValueError: chr() arg not in range(0x110000)

# %% [markdown]
# Let's fix encode by catching the ValueError and raising a mesage:

# %%
def better_encode(text: str, shift: int = 3) -> str:
    try:
        encoded_chars = [chr(ord(char) + shift) for char in text]
        return ''.join(encoded_chars)
    except ValueError:
        # print(f"Shift {shift} may be out of bounds")
        raise ValueError("Shift value out of bounds")

# %% [markdown]
# We'll also tweak the ghostwriter to ignore ValueErrors now that we have them handled in-function

# %%
print(ghostwriter.roundtrip(better_encode, decode, except_=ValueError))
# Out:
# # This test code was written by the `hypothesis.extra.ghostwriter` module
# # and is provided under the Creative Commons Zero public domain dedication.
#
# from hypothesis import given, reject, strategies as st
#
#
# @given(shift=st.integers(), text=st.text())
# def test_roundtrip_better_encode_decode(shift: int, text: str) -> None:
#     try:
#         value0 = better_encode(text=text, shift=shift)
#         value1 = decode(text=value0, shift=shift)
#     except ValueError:
#         reject()
#     assert text == value1, (text, value1)

# %%
from hypothesis import reject

@given(shift=st.integers(), text=st.text())
def test_roundtrip_better_encode_decode(shift: int, text: str) -> None:
    try:
        value0 = better_encode(text=text, shift=shift)
        value1 = decode(text=value0, shift=shift)
    except ValueError:
        reject()
    assert text == value1, (text, value1)

test_roundtrip_better_encode_decode()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[114], line 12
#       9         reject()
#      10     assert text == value1, (text, value1)
# ---> 12 test_roundtrip_better_encode_decode()
#
# Cell In[114], line 4, in test_roundtrip_better_encode_decode()
#       1 from hypothesis import reject
#       3 @given(shift=st.integers(), text=st.text())
# ----> 4 def test_roundtrip_better_encode_decode(shift: int, text: str) -> None:
#       5     try:
#       6         value0 = better_encode(text=text, shift=shift)
#
#     [... skipping hidden 1 frame]
#
# Cell In[114], line 6, in test_roundtrip_better_encode_decode(shift, text)
#       3 @given(shift=st.integers(), text=st.text())
#       4 def test_roundtrip_better_encode_decode(shift: int, text: str) -> None:
#       5     try:
# ----> 6         value0 = better_encode(text=text, shift=shift)
#       7         value1 = decode(text=value0, shift=shift)
#       8     except ValueError:
#
# Cell In[113], line 3, in better_encode(text, shift)
#       1 def better_encode(text: str, shift: int = 3) -> str:
#       2     try:
# ----> 3         encoded_chars = [chr(ord(char) + shift) for char in text]
#       4         return ''.join(encoded_chars)
#       5     except ValueError:
#       6         # print(f"Shift {shift} may be out of bounds")
#
# OverflowError: Python int too large to convert to C int
# Falsifying example: test_roundtrip_better_encode_decode(
#     shift=2_147_483_600,
#     text='0',
# )
# Explanation:
#     These lines were always and only run by failing examples:
#         C:\Users\seanm\AppData\Local\Temp\ipykernel_43632\3963345231.py:5

# %% [markdown]
# It looks like there's another problem. If the shift value is too big there is an overflow error:
# ```
# OverflowError: Python int too large to convert to C int
# Falsifying example: test_roundtrip_better_encode_decode(
#     shift=2_147_483_600,
#     text='0',
# )
# ```
#
# Let's fix that and twek the ghostwriter again: Here we catch Overflow errors where the shift value is too large or small and raise a useful message alongside the error.

# %%
def better_better_encode(text: str, shift: int = 3) -> str:
    try:
        encoded_chars = []
        for char in text:
            new_code = ord(char) + shift
            if new_code > 0x10FFFF:
                raise OverflowError(f"Shift {shift} results in an overflow for character {char}")
            encoded_chars.append(chr(new_code))
        return ''.join(encoded_chars)
    except (ValueError, OverflowError) as e:
        if e is OverflowError:
            raise e
        else: 
            raise ValueError("Shift value out of bounds")

# %%
def better_decode(text: str, shift: int = 3) -> str:
    try:
        decoded_chars = []
        for char in text:
            new_code = ord(char) - shift
            if new_code < 0:
                raise OverflowError(f"Shift {shift} results in an underflow for character {char}")
            decoded_chars.append(chr(new_code))
        return ''.join(decoded_chars)
    except (ValueError, OverflowError) as e:
        if e is OverflowError:
            raise e
        else: 
            raise ValueError("Shift value out of bounds")

# %%
print(ghostwriter.roundtrip(better_better_encode, better_decode, except_=(ValueError, OverflowError)))
# Out:
# # This test code was written by the `hypothesis.extra.ghostwriter` module
# # and is provided under the Creative Commons Zero public domain dedication.
#
# from hypothesis import given, reject, strategies as st
#
#
# @given(shift=st.integers(), text=st.text())
# def test_roundtrip_better_better_encode_better_decode(shift: int, text: str) -> None:
#     try:
#         value0 = better_better_encode(text=text, shift=shift)
#         value1 = better_decode(text=value0, shift=shift)
#     except (OverflowError, ValueError):
#         reject()
#     assert text == value1, (text, value1)

# %%
@given(shift=st.integers(), text=st.text())
def test_roundtrip_better_better_encode_better_decode(shift: int, text: str) -> None:
    try:
        value0 = better_better_encode(text=text, shift=shift)
        value1 = better_decode(text=value0, shift=shift)
    except (OverflowError, ValueError):
        reject()
    assert text == value1, (text, value1)
    
test_roundtrip_better_better_encode_better_decode()

# %% [markdown]
# The test passes so now we have an encode and decode Cesar function that works as we expect and only fails in ways that we expect and can handle!

# %% [markdown]
# # Review:

# %% [markdown]
# Hypothesis helps you:
# 1. Automatically think of and write test cases you couldn't dream of!
# 2. Generate arbitarily complex test payloads, from strings to jsons to dataframes!
# 3. Write test functions automatically!
# 4. Write better code by ensuring your programs never fail in an unexpected way!
#
# MacIver, D. R., Hatfield-Dodds, Z., & many other contributors. (2019). Hypothesis: A new approach to property-based testing. https://doi.org/10.21105/joss.01891
